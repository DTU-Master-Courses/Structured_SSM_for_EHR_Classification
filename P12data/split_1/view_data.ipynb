# %%
import numpy as np
import pandas as pd

# Load the .npy file
data = np.load('test_physionet2012_1.npy', allow_pickle=True)

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Display the first 100 rows
df.head(100)
# Out:
#                                                     0
# 0   {'ts_values': [[0.16966099858624017, 0.0, 0.0,...
# 1   {'ts_values': [[-0.32848355450987454, 0.0, 0.0...
# 2   {'ts_values': [[-0.9359767612187836, 0.0, 0.0,...
# 3   {'ts_values': [[-0.9481265944542595, 0.0, 0.0,...
# 4   {'ts_values': [[-0.5755307301074263, 0.0, 0.0,...
# ..                                                ...
# 95  {'ts_values': [[-0.7982782392340263, 0.0, 0.0,...
# 96  {'ts_values': [[-1.312622518479605, 0.0, 0.0, ...
# 97  {'ts_values': [[-0.5309812900795109, 0.0, 0.0,...
# 98  {'ts_values': [[-0.4499821958516564, 0.0, 0.0,...
# 99  {'ts_values': [[-1.5029704208137653, 0.0, 0.0,...
#
# [100 rows x 1 columns]

# %%
import h5py
import pandas as pd
import os

# Check the current working directory
print(os.getcwd())

# Provide the full path to the .h5 file
file_path = 'C:/MyGitHub/Structured_SSM_for_EHR_Classification/processed_datasets/physionet2012_1_neg.h5'

# Open the .h5 file
with h5py.File(file_path, 'r') as f:
    # List all groups
    print(list(f.keys()))

    # Get the data
    data = f['label_array'][:]

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Display the first 100 rows
df.head(100)
# Out:
# c:\MyGitHub\Structured_SSM_for_EHR_Classification\P12data\split_1
# ['data_array', 'delta_array', 'label_array', 'sensor_mask_array', 'static_array', 'times_array']
#     0
# 0   0
# 1   0
# 2   0
# 3   0
# 4   0
# .. ..
# 95  0
# 96  0
# 97  0
# 98  0
# 99  0
#
# [100 rows x 1 columns]
